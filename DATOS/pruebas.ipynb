# %%
import requests
import pandas as pd

url = "https://imdb-top-100-movies.p.rapidapi.com/"

headers = {
	"X-RapidAPI-Key": "1ef09404c0msha8762538d43bb96p1e0e55jsn18bf1e4617a1",
	"X-RapidAPI-Host": "imdb-top-100-movies.p.rapidapi.com"
}

response = requests.get(url, headers=headers)
json_data = response.json()
df = pd.DataFrame(json_data)

# %%
df.head(1)
# Out:
#    rank                     title  \
# 0     1  The Shawshank Redemption
#
#                                            thumbnail rating    id  year  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...    9.3  top1  1994
#
#                                                image  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                                          description  \
# 0  Two imprisoned men bond over a number of years...
#
#                                      trailer    genre          director  \
# 0  https://www.youtube.com/embed/NmzuHjWmXOc  [Drama]  [Frank Darabont]
#
#                                              writers     imdbid
# 0  [Stephen King (based on the short novel "Rita ...  tt0111161

# %%
my_df = df[['title', 'rating', 'year', 'image']].copy()
my_df.head(5)
# Out:
#                       title rating  year  \
# 0  The Shawshank Redemption    9.3  1994
# 1             The Godfather    9.2  1972
# 2           The Dark Knight    9.0  2008
# 3     The Godfather Part II    9.0  1974
# 4              12 Angry Men    9.0  1957
#
#                                                image
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...

# %%
my_df['genre'] = df['genre'].apply(lambda x: x[0])
my_df['director'] = df['director'].apply(lambda x: x[0])
my_df.head(5)
# Out:
#                       title rating  year  \
# 0  The Shawshank Redemption    9.3  1994
# 1             The Godfather    9.2  1972
# 2           The Dark Knight    9.0  2008
# 3     The Godfather Part II    9.0  1974
# 4              12 Angry Men    9.0  1957
#
#                                                image   genre  \
# 0  https://m.media-amazon.com/images/M/MV5BMDFkYT...   Drama
# 1  https://m.media-amazon.com/images/M/MV5BM2MyNj...   Crime
# 2  https://m.media-amazon.com/images/M/MV5BMTMxNT...  Action
# 3  https://m.media-amazon.com/images/M/MV5BMWMwMG...   Crime
# 4  https://m.media-amazon.com/images/M/MV5BMWU4N2...   Crime
#
#                director
# 0        Frank Darabont
# 1  Francis Ford Coppola
# 2     Christopher Nolan
# 3  Francis Ford Coppola
# 4          Sidney Lumet

# %%
var = cursor.execute("""SELECT * FROM filmes""")
# Out:
# 1.4.27
