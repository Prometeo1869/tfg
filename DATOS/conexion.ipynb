# %%
import mysql.connector
from api_to_dataframe import df
from sqlalchemy import create_engine

conn = mysql.connector.connect(
    host = "127.0.0.1",
    user = "usuario",
    password = "usuario", 
    port = "3307",
    database = "movies"
)

my_df = df[['id', 'title', 'rating', 'year', 'image']].copy()
my_df['id'] = my_df.index
my_df['rating'] = my_df['rating'].astype(float)
my_df['genre'] = df['genre'].apply(lambda x: x[0])
my_df['director'] = df['director'].apply(lambda x: x[0])

# Crear la conexión a la base de datos MySQL
cursor = conn.cursor()

#Crear la tabla filmes
filmes_table = """CREATE TABLE IF NOT EXISTS filmes (
    id INTEGER PRIMARY KEY,
    title VARCHAR(80),
    rating FLOAT,
    year YEAR,
    image VARCHAR(180),
    genre VARCHAR(20),
    director VARCHAR(40)
)"""

cursor.execute(filmes_table)

# Guardar los datos en la tabla filmes
engine = create_engine('mysql+mysqlconnector://usuario:usuario@127.0.0.1:3307/movies')

my_df.to_sql('filmes', con=engine, if_exists='append', index=False)

conn.commit()

conn.close()
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1782                     self.dialect.do_executemany(
# -> 1783                         cursor, statement, parameters, context
#    1784                     )
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     715     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 716         cursor.executemany(statement, parameters)
#     717
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\cursor.py in executemany(self, operation, seq_params)
#     720                 self._executed = stmt
# --> 721                 return self.execute(stmt)
#     722
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     614         try:
# --> 615             self._handle_result(self._connection.cmd_query(stmt))
#     616         except InterfaceError as err:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#    1045         try:
# -> 1046             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#    1047         except ProgrammingError as err:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     823         if packet[4] == 255:
# --> 824             raise get_exception(packet)
#     825
#
# IntegrityError: 1062 (23000): Duplicate entry '0' for key 'filmes.PRIMARY'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6012\3510989081.py in <module>
#      35 engine = create_engine('mysql+mysqlconnector://usuario:usuario@127.0.0.1:3307/movies')
#      36
# ---> 37 my_df.to_sql('filmes', con=engine, if_exists='append', index=False)
#      38
#      39 cursor.execute("""SELECT * FROM filmes""")
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1768             chunksize=chunksize,
#    1769             method=method,
# -> 1770             **engine_kwargs,
#    1771         )
#    1772
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1348                 raise ValueError("inf cannot be used with MySQL") from err
#    1349             else:
# -> 1350                 raise err
#    1351
#    1352
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1338
#    1339         try:
# -> 1340             table.insert(chunksize=chunksize, method=method)
#    1341         except exc.SQLAlchemyError as err:
#    1342             # GH34431
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     965
#     966                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 967                 exec_insert(conn, keys, chunk_iter)
#     968
#     969     def _query_iterator(
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     880         """
#     881         data = [dict(zip(keys, row)) for row in data_iter]
# --> 882         conn.execute(self.table.insert(), data)
#     883
#     884     def _execute_insert_multi(self, conn, keys: list[str], data_iter):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1287             )
#    1288         else:
# -> 1289             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1290
#    1291     def _execute_function(self, func, multiparams, params, execution_options):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     324         if _force or self.supports_execution:
#     325             return connection._execute_clauseelement(
# --> 326                 self, multiparams, params, execution_options
#     327             )
#     328         else:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1489             elem,
#    1490             extracted_params,
# -> 1491             cache_hit=cache_hit,
#    1492         )
#    1493         if has_events:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844         except BaseException as e:
#    1845             self._handle_dbapi_exception(
# -> 1846                 e, statement, parameters, cursor, context
#    1847             )
#    1848
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2025             elif should_wrap:
#    2026                 util.raise_(
# -> 2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#    2029             else:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1781                 if not evt_handled:
#    1782                     self.dialect.do_executemany(
# -> 1783                         cursor, statement, parameters, context
#    1784                     )
#    1785             elif not parameters and context.no_parameters:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\sqlalchemy\engine\default.py in do_executemany(self, cursor, statement, parameters, context)
#     714
#     715     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 716         cursor.executemany(statement, parameters)
#     717
#     718     def do_execute(self, cursor, statement, parameters, context=None):
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\cursor.py in executemany(self, operation, seq_params)
#     719             if stmt is not None:
#     720                 self._executed = stmt
# --> 721                 return self.execute(stmt)
#     722
#     723         rowcnt = 0
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     613
#     614         try:
# --> 615             self._handle_result(self._connection.cmd_query(stmt))
#     616         except InterfaceError as err:
#     617             if self._connection.have_next_result:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#    1044         query = bytes(packet)
#    1045         try:
# -> 1046             result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#    1047         except ProgrammingError as err:
#    1048             if err.errno == 3948 and "Loading local data is disabled" in err.msg:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     822             return self._handle_eof(packet)
#     823         if packet[4] == 255:
# --> 824             raise get_exception(packet)
#     825
#     826         # We have a text result set
#
# IntegrityError: (mysql.connector.errors.IntegrityError) 1062 (23000): Duplicate entry '0' for key 'filmes.PRIMARY'
# [SQL: INSERT INTO filmes (id, title, rating, year, image, genre, director) VALUES (%(id)s, %(title)s, %(rating)s, %(year)s, %(image)s, %(genre)s, %(director)s)]
# [parameters: ({'id': 0, 'title': 'The Shawshank Redemption', 'rating': 9.3, 'year': 1994, 'image': 'https://m.media-amazon.com/images/M/MV5BMDFkYTc0MGEtZmNhMC00ZDIzLWFmNTEtODM1ZmRlYWMwMWFmXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_QL75_UX380_CR0,1,380,562_.jpg', 'genre': 'Drama', 'director': 'Frank Darabont'}, {'id': 1, 'title': 'The Godfather', 'rating': 9.2, 'year': 1972, 'image': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR8,0,380,562_.jpg', 'genre': 'Crime', 'director': 'Francis Ford Coppola'}, {'id': 2, 'title': 'The Dark Knight', 'rating': 9.0, 'year': 2008, 'image': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'genre': 'Action', 'director': 'Christopher Nolan'}, {'id': 3, 'title': 'The Godfather Part II', 'rating': 9.0, 'year': 1974, 'image': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR7,0,380,562_.jpg', 'genre': 'Crime', 'director': 'Francis Ford Coppola'}, {'id': 4, 'title': '12 Angry Men', 'rating': 9.0, 'year': 1957, 'image': 'https://m.media-amazon.com/images/M/MV5BMWU4N2FjNzYtNTVkNC00NzQ0LTg0MjAtYTJlMjFhNGUxZDFmXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,11,380,562_.jpg', 'genre': 'Crime', 'director': 'Sidney Lumet'}, {'id': 5, 'title': "Schindler's List", 'rating': 8.9, 'year': 1993, 'image': 'https://m.media-amazon.com/images/M/MV5BNDE4OTMxMTctNmRhYy00NWE2LTg3YzItYTk3M2UwOTU5Njg4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_QL75_UX380_CR0,4,380,562_.jpg', 'genre': 'Biography', 'director': 'Steven Spielberg'}, {'id': 6, 'title': 'The Lord of the Rings: The Return of the King', 'rating': 8.9, 'year': 2003, 'image': 'https://m.media-amazon.com/images/M/MV5BNzA5ZDNlZWMtM2NhNS00NDJjLTk4NDItYTRmY2EwMWZlMTY3XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UX380_CR0,0,380,562_.jpg', 'genre': 'Action', 'director': 'Peter Jackson'}, {'id': 7, 'title': 'Pulp Fiction', 'rating': 8.8, 'year': 1994, 'image': 'https://m.media-amazon.com/images/M/MV5BNGNhMDIzZTUtNTBlZi00MTRlLWFjM2ItYzViMjE3YzI5MjljXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_QL75_UY562_CR3,0,380,562_.jpg', 'genre': 'Crime', 'director': 'Quentin Tarantino'}  ... displaying 10 of 100 total bound parameter sets ...  {'id': 98, 'title': 'North by Northwest', 'rating': 8.2, 'year': 1959, 'image': 'https://m.media-amazon.com/images/M/MV5BZDA3NDExMTUtMDlhOC00MmQ5LWExZGUtYmI1NGVlZWI4OWNiXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,5,380,562_.jpg', 'genre': 'Action', 'director': 'Alfred Hitchcock'}, {'id': 99, 'title': 'Vertigo', 'rating': 8.2, 'year': 1958, 'image': 'https://m.media-amazon.com/images/M/MV5BYTE4ODEwZDUtNDFjOC00NjAxLWEzYTQtYTI1NGVmZmFlNjdiL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_QL75_UX380_CR0,13,380,562_.jpg', 'genre': 'Mystery', 'director': 'Alfred Hitchcock'})]
# (Background on this error at: https://sqlalche.me/e/14/gkpj)
